# %%
pip install langflow
# Out:
# Collecting langflow
#   Downloading langflow-0.0.55.tar.gz (3.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 19.0 MB/s eta 0:00:0000:0100:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting beautifulsoup4<5.0.0,>=4.11.2
#   Downloading beautifulsoup4-4.12.2-py3-none-any.whl (142 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.0/143.0 kB 5.5 MB/s eta 0:00:00
# Collecting rich<14.0.0,>=13.3.3
#   Downloading rich-13.3.3-py3-none-any.whl (238 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 238.7/238.7 kB 9.1 MB/s eta 0:00:00
# Collecting dill<0.4.0,>=0.3.6
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 4.6 MB/s eta 0:00:00
# Collecting gunicorn<21.0.0,>=20.1.0
#   Downloading gunicorn-20.1.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 2.9 MB/s eta 0:00:00
# Collecting fastapi<0.93.0,>=0.92.0
#   Downloading fastapi-0.92.0-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.2/56.2 kB 2.0 MB/s eta 0:00:00
# Collecting openai<0.28.0,>=0.27.2
#   Downloading openai-0.27.4-py3-none-any.whl (70 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.3/70.3 kB 2.9 MB/s eta 0:00:00
# Collecting langchain<0.0.132,>=0.0.131
#   Downloading langchain-0.0.131-py3-none-any.whl (477 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 477.2/477.2 kB 15.1 MB/s eta 0:00:00
# Collecting typer<0.8.0,>=0.7.0
#   Downloading typer-0.7.0-py3-none-any.whl (38 kB)
# Collecting google-api-python-client<3.0.0,>=2.79.0
#   Downloading google_api_python_client-2.84.0-py2.py3-none-any.whl (11.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.2/11.2 MB 38.9 MB/s eta 0:00:0000:0100:01
# Collecting pandas<2.0.0,>=1.5.3
#   Downloading pandas-1.5.3-cp310-cp310-macosx_10_9_x86_64.whl (12.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 19.2 MB/s eta 0:00:0000:0100:01
# Collecting huggingface-hub<0.14.0,>=0.13.3
#   Downloading huggingface_hub-0.13.4-py3-none-any.whl (200 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.1/200.1 kB 8.0 MB/s eta 0:00:00
# Collecting google-search-results<3.0.0,>=2.4.1
#   Downloading google_search_results-2.4.2.tar.gz (18 kB)
#   Preparing metadata (setup.py) ... done
# Collecting uvicorn<0.21.0,>=0.20.0
#   Downloading uvicorn-0.20.0-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.9/56.9 kB 2.1 MB/s eta 0:00:00
# Collecting types-pyyaml<7.0.0.0,>=6.0.12.8
#   Downloading types_PyYAML-6.0.12.9-py3-none-any.whl (14 kB)
# Collecting soupsieve>1.2
#   Downloading soupsieve-2.4-py3-none-any.whl (37 kB)
# Collecting starlette<0.26.0,>=0.25.0
#   Downloading starlette-0.25.0-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 2.3 MB/s eta 0:00:00
# Collecting pydantic!=1.7,!=1.7.1,!=1.7.2,!=1.7.3,!=1.8,!=1.8.1,<2.0.0,>=1.6.2
#   Downloading pydantic-1.10.7-cp310-cp310-macosx_10_9_x86_64.whl (2.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 31.6 MB/s eta 0:00:0000:0100:01
# Collecting google-auth-httplib2>=0.1.0
#   Downloading google_auth_httplib2-0.1.0-py2.py3-none-any.whl (9.3 kB)
# Collecting uritemplate<5,>=3.0.1
#   Downloading uritemplate-4.1.1-py2.py3-none-any.whl (10 kB)
# Collecting google-auth<3.0.0dev,>=1.19.0
#   Downloading google_auth-2.17.2-py2.py3-none-any.whl (178 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.2/178.2 kB 6.9 MB/s eta 0:00:00
# Collecting google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5
#   Downloading google_api_core-2.11.0-py3-none-any.whl (120 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.3/120.3 kB 4.4 MB/s eta 0:00:00
# Collecting httplib2<1dev,>=0.15.0
#   Downloading httplib2-0.22.0-py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.9/96.9 kB 3.6 MB/s eta 0:00:00
# Collecting requests
#   Downloading requests-2.28.2-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: setuptools>=3.0 in /usr/local/lib/python3.10/site-packages (from gunicorn<21.0.0,>=20.1.0->langflow) (67.2.0)
# Collecting tqdm>=4.42.1
#   Downloading tqdm-4.65.0-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.1/77.1 kB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.9 in /Users/ethan.jensen/Library/Python/3.10/lib/python/site-packages (from huggingface-hub<0.14.0,>=0.13.3->langflow) (23.0)
# Collecting typing-extensions>=3.7.4.3
#   Downloading typing_extensions-4.5.0-py3-none-any.whl (27 kB)
# Collecting filelock
#   Downloading filelock-3.11.0-py3-none-any.whl (10.0 kB)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp310-cp310-macosx_10_9_x86_64.whl (197 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 197.6/197.6 kB 7.5 MB/s eta 0:00:00
# Collecting tenacity<9.0.0,>=8.1.0
#   Downloading tenacity-8.2.2-py3-none-any.whl (24 kB)
# Collecting aiohttp<4.0.0,>=3.8.3
#   Downloading aiohttp-3.8.4-cp310-cp310-macosx_10_9_x86_64.whl (358 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 358.1/358.1 kB 12.0 MB/s eta 0:00:00
# Collecting numpy<2,>=1
#   Downloading numpy-1.24.2-cp310-cp310-macosx_10_9_x86_64.whl (19.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.8/19.8 MB 35.3 MB/s eta 0:00:0000:0100:01
# Collecting SQLAlchemy<2,>=1
#   Downloading SQLAlchemy-1.4.47-cp310-cp310-macosx_11_0_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 26.9 MB/s eta 0:00:0000:01
# Collecting dataclasses-json<0.6.0,>=0.5.7
#   Downloading dataclasses_json-0.5.7-py3-none-any.whl (25 kB)
# Collecting pytz>=2020.1
#   Downloading pytz-2023.3-py2.py3-none-any.whl (502 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 502.3/502.3 kB 16.5 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/ethan.jensen/Library/Python/3.10/lib/python/site-packages (from pandas<2.0.0,>=1.5.3->langflow) (2.8.2)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/ethan.jensen/Library/Python/3.10/lib/python/site-packages (from rich<14.0.0,>=13.3.3->langflow) (2.14.0)
# Collecting markdown-it-py<3.0.0,>=2.2.0
#   Downloading markdown_it_py-2.2.0-py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.5/84.5 kB 3.1 MB/s eta 0:00:00
# Collecting click<9.0.0,>=7.1.1
#   Downloading click-8.1.3-py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.6/96.6 kB 3.8 MB/s eta 0:00:00
# Collecting h11>=0.8
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 2.2 MB/s eta 0:00:00
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.3-cp310-cp310-macosx_10_9_x86_64.whl (35 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp310-cp310-macosx_10_9_x86_64.whl (29 kB)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting charset-normalizer<4.0,>=2.0
#   Downloading charset_normalizer-3.1.0-cp310-cp310-macosx_10_9_x86_64.whl (124 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.8/124.8 kB 5.3 MB/s eta 0:00:00
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.8.2-cp310-cp310-macosx_10_9_x86_64.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 2.4 MB/s eta 0:00:00
# Collecting attrs>=17.3.0
#   Downloading attrs-22.2.0-py3-none-any.whl (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 2.4 MB/s eta 0:00:00
# Collecting typing-inspect>=0.4.0
#   Downloading typing_inspect-0.8.0-py3-none-any.whl (8.7 kB)
# Collecting marshmallow-enum<2.0.0,>=1.5.1
#   Downloading marshmallow_enum-1.5.1-py2.py3-none-any.whl (4.2 kB)
# Collecting marshmallow<4.0.0,>=3.3.0
#   Downloading marshmallow-3.19.0-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 kB 1.6 MB/s eta 0:00:00
# Collecting googleapis-common-protos<2.0dev,>=1.56.2
#   Downloading googleapis_common_protos-1.59.0-py2.py3-none-any.whl (223 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 223.6/223.6 kB 8.3 MB/s eta 0:00:00
# Collecting protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5
#   Downloading protobuf-4.22.1-cp37-abi3-macosx_10_9_universal2.whl (397 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 397.2/397.2 kB 13.2 MB/s eta 0:00:00
# Collecting cachetools<6.0,>=2.0.0
#   Downloading cachetools-5.3.0-py3-none-any.whl (9.3 kB)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 6.0 MB/s eta 0:00:00
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Requirement already satisfied: six>=1.9.0 in /Users/ethan.jensen/Library/Python/3.10/lib/python/site-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client<3.0.0,>=2.79.0->langflow) (1.16.0)
# Collecting pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2
#   Downloading pyparsing-3.0.9-py3-none-any.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.3/98.3 kB 3.7 MB/s eta 0:00:00
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Collecting idna<4,>=2.5
#   Downloading idna-3.4-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.5/61.5 kB 2.2 MB/s eta 0:00:00
# Collecting urllib3<1.27,>=1.21.1
#   Downloading urllib3-1.26.15-py2.py3-none-any.whl (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.9/140.9 kB 5.6 MB/s eta 0:00:00
# Collecting certifi>=2017.4.17
#   Downloading certifi-2022.12.7-py3-none-any.whl (155 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 5.9 MB/s eta 0:00:00
# Collecting greenlet!=0.4.17
#   Downloading greenlet-2.0.2-cp310-cp310-macosx_11_0_x86_64.whl (242 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.1/242.1 kB 7.7 MB/s eta 0:00:00
# Collecting anyio<5,>=3.4.0
#   Downloading anyio-3.6.2-py3-none-any.whl (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.6/80.6 kB 3.2 MB/s eta 0:00:00
# Collecting sniffio>=1.1
#   Downloading sniffio-1.3.0-py3-none-any.whl (10 kB)
# Collecting pyasn1<0.5.0,>=0.4.6
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.1/77.1 kB 3.0 MB/s eta 0:00:00
# Collecting mypy-extensions>=0.3.0
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Building wheels for collected packages: langflow, google-search-results
#   Building wheel for langflow (pyproject.toml) ... done
#   Created wheel for langflow: filename=langflow-0.0.55-py3-none-any.whl size=4177931 sha256=0c8ae3f1429e3eb1b8b66822bd247f23d4559b4d62f6023c1c3f1aa9bc99f14a
#   Stored in directory: /Users/ethan.jensen/Library/Caches/pip/wheels/fd/7d/40/f59e8b92a567d645c68c35f825baf4e6abd7e7800f05330a72
#   Building wheel for google-search-results (setup.py) ... done
#   Created wheel for google-search-results: filename=google_search_results-2.4.2-py3-none-any.whl size=32003 sha256=79be3028076dc486f00db5d7ad7eca2f9f8c913cc11de61868408e03a65d5777
#   Stored in directory: /Users/ethan.jensen/Library/Caches/pip/wheels/d3/b2/c3/03302d12bb44a2cdff3c9371f31b72c0c4e84b8d2285eeac53
# Successfully built langflow google-search-results
# Installing collected packages: types-pyyaml, pytz, pyasn1, urllib3, uritemplate, typing-extensions, tqdm, tenacity, soupsieve, sniffio, rsa, pyyaml, pyparsing, pyasn1-modules, protobuf, numpy, mypy-extensions, multidict, mdurl, marshmallow, idna, h11, gunicorn, greenlet, frozenlist, filelock, dill, click, charset-normalizer, certifi, cachetools, attrs, async-timeout, yarl, uvicorn, typing-inspect, typer, SQLAlchemy, requests, pydantic, pandas, marshmallow-enum, markdown-it-py, httplib2, googleapis-common-protos, google-auth, beautifulsoup4, anyio, aiosignal, starlette, rich, huggingface-hub, google-search-results, google-auth-httplib2, google-api-core, dataclasses-json, aiohttp, openai, langchain, google-api-python-client, fastapi, langflow
# Successfully installed SQLAlchemy-1.4.47 aiohttp-3.8.4 aiosignal-1.3.1 anyio-3.6.2 async-timeout-4.0.2 attrs-22.2.0 beautifulsoup4-4.12.2 cachetools-5.3.0 certifi-2022.12.7 charset-normalizer-3.1.0 click-8.1.3 dataclasses-json-0.5.7 dill-0.3.6 fastapi-0.92.0 filelock-3.11.0 frozenlist-1.3.3 google-api-core-2.11.0 google-api-python-client-2.84.0 google-auth-2.17.2 google-auth-httplib2-0.1.0 google-search-results-2.4.2 googleapis-common-protos-1.59.0 greenlet-2.0.2 gunicorn-20.1.0 h11-0.14.0 httplib2-0.22.0 huggingface-hub-0.13.4 idna-3.4 langchain-0.0.131 langflow-0.0.55 markdown-it-py-2.2.0 marshmallow-3.19.0 marshmallow-enum-1.5.1 mdurl-0.1.2 multidict-6.0.4 mypy-extensions-1.0.0 numpy-1.24.2 openai-0.27.4 pandas-1.5.3 protobuf-4.22.1 pyasn1-0.4.8 pyasn1-modules-0.2.8 pydantic-1.10.7 pyparsing-3.0.9 pytz-2023.3 pyyaml-6.0 requests-2.28.2 rich-13.3.3 rsa-4.9 sniffio-1.3.0 soupsieve-2.4 starlette-0.25.0 tenacity-8.2.2 tqdm-4.65.0 typer-0.7.0 types-pyyaml-6.0.12.9 typing-extensions-4.5.0 typing-inspect-0.8.0 uritemplate-4.1.1 urllib3-1.26.15 uvicorn-0.20.0 yarl-1.8.2
#
# [notice] A new release of pip is available: 23.0 -> 23.0.1
# [notice] To update, run: python3.10 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# May need to update kernal or pip
#
# [notice] A new release of pip is available: 23.0 -> 23.0.1
#
# [notice] To update, run: python3.10 -m pip install --upgrade pip
#
# Note: you may need to restart the kernel to use updated packages.
# ![image.png](attachment:image.png)

# %% [markdown]
# In your terminal type langflow to run it
# Then cick or open the http port it's running on.
# ![image.png](attachment:image.png)

# %% [markdown]
# Install networkx for addtional memory features

# %%
pip install networkx
# Out:
# Collecting networkx
#   Downloading networkx-3.1-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 15.4 MB/s eta 0:00:0000:0100:01
# Installing collected packages: networkx
# Successfully installed networkx-3.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install openai
# Out:
# Requirement already satisfied: openai in /usr/local/lib/python3.10/site-packages (0.27.4)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.10/site-packages (from openai) (2.28.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/site-packages (from openai) (4.65.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/site-packages (from openai) (3.8.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/site-packages (from requests>=2.20->openai) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/site-packages (from requests>=2.20->openai) (3.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/site-packages (from requests>=2.20->openai) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/site-packages (from requests>=2.20->openai) (1.26.15)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/site-packages (from aiohttp->openai) (1.8.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/site-packages (from aiohttp->openai) (4.0.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/site-packages (from aiohttp->openai) (6.0.4)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/site-packages (from aiohttp->openai) (22.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/site-packages (from aiohttp->openai) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/site-packages (from aiohttp->openai) (1.3.1)
# Note: you may need to restart the kernel to use updated packages.
